# %% [markdown]
# ### first use the library of numpy and panda

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %% [markdown]
# ### then understand the data ( Exploratory data analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.size
# Out:
# 119880

# %%
df.describe()
# it always describes numeric data

# here in 25% of data is less than the given data. and so on with other.
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df['bath'].describe()
# Out:
# count    13247.000000
# mean         2.692610
# std          1.341458
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         40.000000
# Name: bath, dtype: float64

# %% [markdown]
# ### data uniqueness check

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df['area_type'].unique()
#to check separate unique values in columns
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %% [markdown]
# ### check the dimension of whole and single column

# %%
df.ndim
#obviously 2 dimension
# Out:
# 2

# %%
df['area_type'].ndim
# Out:
# 1

# %% [markdown]
# ### check the value counts

# %%
df.value_counts()
# Out:
# area_type             availability   location                        size   society  total_sqft   bath  balcony  price
# Super built-up  Area  Ready To Move  Haralur Road                    2 BHK  RInceeg  1243         2.0   2.0      46.00     10
#                                      HSR Layout                      2 BHK  NRosete  1140         2.0   2.0      46.00      9
#                                      Parappana Agrahara              2 BHK  Peide L  1194         2.0   2.0      47.00      7
#                       21-Dec         Kanakpura Road                  3 BHK  PrarePa  1100         3.0   2.0      53.00      5
#                       Ready To Move  Raja Rajeshwari Nagar           2 BHK  GrrvaGr  1196         2.0   2.0      40.54      5
#                                                                                                                            ..
# ...

# %%
df['area_type'].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %% [markdown]
# ### to check categorical and numerical data in a dataframe

# %%
df.dtypes
#here object referred to as categorical data.
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
numerics=['int16','int32','int64','float16','float32','float64']
numeric_df=df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 3

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df['area_type'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### check null values tomorrow

# %%
df.isna()
#here in data if false is written then data is okay 
#but if true is shown then there must be null values
# this isna() shows all every data in a dataframe
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False     True       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
df.isna().any()
#it comprises in only column data that if there is null or not null
# Out:
# area_type       False
# availability    False
# location         True
# size             True
# society          True
# total_sqft      False
# bath             True
# balcony          True
# price           False
# dtype: bool

# %%
df.isna().sum()
#here sum tells it adds and shows how many data have null values
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=True)
# Out:
# area_type          0
# availability       0
# total_sqft         0
# price              0
# location           1
# size              16
# bath              73
# balcony          609
# society         5502
# dtype: int64

# %%
percentage_df=df.isna().sum().sort_values(ascending=True)/len(df)
percentage_df
# Out:
# area_type       0.000000
# availability    0.000000
# total_sqft      0.000000
# price           0.000000
# location        0.000075
# size            0.001201
# bath            0.005480
# balcony         0.045721
# society         0.413063
# dtype: float64

# %%
percentage_df[percentage_df!=0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['size'].isna().sum()
# Out:
# 16

# %%
df.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False     True       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.isnull().sum().sum()
#adds all duplication/null values in a one digit.
# Out:
# 6201

# %%
df.notnull()
# opposite to that of isnull
# Out:
#        area_type  availability  location  size  society  total_sqft  bath  \
# 0           True          True      True  True     True        True  True
# 1           True          True      True  True     True        True  True
# 2           True          True      True  True    False        True  True
# 3           True          True      True  True     True        True  True
# 4           True          True      True  True    False        True  True
# ...          ...           ...       ...   ...      ...         ...   ...
# 13315       True          True      True  True     True        True  True
# 13316       True          True      True  True    False        True  True
# 13317       True          True      True  True     True        True  True
# 13318       True          True      True  True     True        True  True
# 13319       True          True      True  True    False        True  True
#
#        balcony  price
# 0         True   True
# 1         True   True
# ...

# %%
df.notnull().sum().sum()
# Out:
# 113679

# %% [markdown]
# ### check duplicate values

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319     True
# Length: 13320, dtype: bool

# %%
df.duplicated().sum()
# in above part we can't see that duplicated values but 
# sum takes all duplicated values
# Out:
# 529

# %%
df.duplicated(subset=['area_type'])
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 13315     True
# 13316     True
# 13317     True
# 13318     True
# 13319     True
# Length: 13320, dtype: bool

# %%
df.duplicated(subset=['area_type']).value_counts()
# Out:
# True     13316
# False        4
# dtype: int64

# %%
df[df.duplicated(subset=['area_type'],keep='first')]
# Out:
#                   area_type   availability               location       size  \
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# 6      Super built-up  Area         18-May       Old Airport Road      4 BHK
# 7      Super built-up  Area  Ready To Move           Rajaji Nagar      4 BHK
# ...                     ...            ...                    ...        ...
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %% [markdown]
# ### cleaning/filtering/dropping/removing/removing duplicated values

# %%
df.fillna(value=0)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.dropna()
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.dropna(how="all")
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.drop_duplicates()
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.drop(['area_type','availability','society'],axis=1)
# Out:
#                        location       size total_sqft  bath  balcony   price
# 0      Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0      1.0   51.00
# ...                         ...        ...        ...   ...      ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0      0.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0      NaN  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0      1.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0      1.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0      1.0   17.00
#
# [13320 rows x 6 columns]

# %% [markdown]
# ### Exploratory analysis and visualization / to check outliers in dataset

# %%
#for this outliers to check 
#we need to import matplotlib, seaborn
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>
