# %% [markdown]
# ### Data exploration
# head, info, size, describe,tail,count,value_counts, shape, ndim,columns

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("sales_returns.csv")
df
# Out:
#             order_id order_date ship_date       ship_mode customer_id  \
# 0     CA-2015-143336   27/08/15  01/09/15    Second Class    ZD-21925
# 1     CA-2015-143336   27/08/15  01/09/15    Second Class    ZD-21925
# 2     CA-2015-143336   27/08/15  01/09/15    Second Class    ZD-21925
# 3     CA-2017-111682   17/06/17  18/06/17     First Class    TB-21055
# 4     CA-2017-111682   17/06/17  18/06/17     First Class    TB-21055
# ...              ...        ...       ...             ...         ...
# 1297  US-2015-143287   11/11/15  17/11/15  Standard Class    KN-16705
# 1298  US-2015-143287   11/11/15  17/11/15  Standard Class    KN-16705
# 1299  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
# 1300  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
# 1301  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
#
#            customer_name  cust_age cust_gender      segment        country  \
# ...

# %%
#here it is showing all data

# %%
df.head()
# Out:
#          order_id order_date ship_date     ship_mode customer_id  \
# 0  CA-2015-143336   27/08/15  01/09/15  Second Class    ZD-21925
# 1  CA-2015-143336   27/08/15  01/09/15  Second Class    ZD-21925
# 2  CA-2015-143336   27/08/15  01/09/15  Second Class    ZD-21925
# 3  CA-2017-111682   17/06/17  18/06/17   First Class    TB-21055
# 4  CA-2017-111682   17/06/17  18/06/17   First Class    TB-21055
#
#         customer_name  cust_age cust_gender   segment        country  ...  \
# 0  Zuschuss Donatelli        19      Female  Consumer  United States  ...
# 1  Zuschuss Donatelli        19      Female  Consumer  United States  ...
# 2  Zuschuss Donatelli        19      Female  Consumer  United States  ...
# 3     Ted Butterfield        20      Female  Consumer  United States  ...
# 4     Ted Butterfield        20      Female  Consumer  United States  ...
#
#   region       product_id         category sub_category  \
# 0   West  OFF-AR-10003056  Office Supplies          Art
# ...

# %%
#df.head() shows only 5 rows on top

# %%
df.tail()
# Out:
#             order_id order_date ship_date       ship_mode customer_id  \
# 1297  US-2015-143287   11/11/15  17/11/15  Standard Class    KN-16705
# 1298  US-2015-143287   11/11/15  17/11/15  Standard Class    KN-16705
# 1299  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
# 1300  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
# 1301  CA-2018-121258   26/02/18  03/03/18  Standard Class    DB-13060
#
#       customer_name  cust_age cust_gender      segment        country  ...  \
# 1297  Kristina Nunn        19      Female  Home Office  United States  ...
# 1298  Kristina Nunn        24        Male  Home Office  United States  ...
# 1299    Dave Brooks        21      Female     Consumer  United States  ...
# 1300    Dave Brooks        23      Female     Consumer  United States  ...
# 1301    Dave Brooks        21      Female     Consumer  United States  ...
#
#      region       product_id         category sub_category  \
# ...

# %%
#df.tail() shows only 5 rows on bottom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1302 non-null   object
#  1   order_date     1302 non-null   object
#  2   ship_date      1302 non-null   object
#  3   ship_mode      1302 non-null   object
#  4   customer_id    1302 non-null   object
#  5   customer_name  1302 non-null   object
#  6   cust_age       1302 non-null   int64
#  7   cust_gender    1302 non-null   object
#  8   segment        1302 non-null   object
#  9   country        1302 non-null   object
#  10  city           1302 non-null   object
#  11  state          1302 non-null   object
#  12  postal_code    1302 non-null   int64
#  13  region         1302 non-null   object
#  14  product_id     1302 non-null   object
#  15  category       1302 non-null   object
#  16  sub_category   1302 non-null   object
# ...

# %%
df.shape
#it determines rows and columns i.e 1302 rows and 23 columns.
# Out:
# (1302, 23)

# %%
df.columns
# it provides detail of all the columns of a dataset.
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'customer_name', 'cust_age', 'cust_gender', 'segment', 'country',
#        'city', 'state', 'postal_code', 'region', 'product_id', 'category',
#        'sub_category', 'product_name', 'sales', 'quantity', 'discount',
#        'profit', 'returned'],
#       dtype='object')

# %%
df['cust_gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
df[['cust_gender','segment','category']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_456\820875862.py in <module>
# ----> 1 df[['cust_gender','segment','category']].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.size
#it determine total no of elements in a datasets.
# Out:
# 29946

# %%
df.ndim
# Out:
# 2

# %%
df['order_id'].ndim
# Out:
# 1

# %%
df.value_counts()
# Out:
# order_id        order_date  ship_date  ship_mode       customer_id  customer_name   cust_age  cust_gender  segment    country        city           state           postal_code  region   product_id       category         sub_category  product_name                                              sales     quantity  discount  profit     returned
# CA-2015-100762  24/11/15    29/11/15   Standard Class  NG-18355     Nat Gilpin      18        Female       Corporate  United States  Jackson        Michigan        49201        Central  OFF-AR-10000380  Office Supplies  Art           Hunt PowerHouse Electric Pencil Sharpener, Blue           151.920   4         0.0        45.5760   True        1
# ...

# %%
df.describe()
#it describes numeric values of all
# Out:
#           cust_age   postal_code         sales     quantity     discount  \
# count  1302.000000   1302.000000   1302.000000  1302.000000  1302.000000
# mean     30.217358  63134.132873    224.062279     3.791859     0.143172
# std      13.065832  32675.934220    599.202039     2.241149     0.197780
# min      18.000000   1841.000000      1.680000     1.000000     0.000000
# 25%      21.000000  32796.750000     19.920000     2.000000     0.000000
# 50%      24.000000  78207.000000     58.081000     3.000000     0.000000
# 75%      38.000000  92374.000000    209.880000     5.000000     0.200000
# max      63.000000  99207.000000  13999.960000    14.000000     0.800000
#
#             profit
# count  1302.000000
# mean     26.911767
# std     278.563765
# min   -3839.990400
# 25%       2.728425
# 50%      10.332000
# 75%      30.469450
# max    6719.980800

# %%
df.nunique()
#it determines the unique values if 1,2,3 is categorical data.
# Out:
# order_id          550
# order_date        426
# ship_date         441
# ship_mode           4
# customer_id       395
# customer_name     395
# cust_age           46
# cust_gender         2
# segment             3
# country             1
# city              185
# state              40
# postal_code       235
# region              4
# product_id        926
# category            3
# sub_category       17
# product_name      920
# sales            1134
# quantity           14
# discount           12
# profit           1198
# returned            2
# dtype: int64
